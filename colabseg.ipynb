# %% [markdown]
# # ColabSeg: Interactive Membrane Segmentation and Analysis

# %%
from colabseg.tensorvoting_wrapper import *
from colabseg.segmentation_gui import *

# %% [markdown]
# # 1) Tensor Voting
#
# This GUI makes use of the TomoSegMemTV tool.<br>
# Please download the tool at and add it to the TV path:<br>
# https://sites.google.com/site/3demimageprocessing/tomosegmemtv <br>
# <font color='red'>**If you use this please Cite:**<br></font>
# **Martinez-Sanchez, A.; Garcia, I.; Asano, S.; Lucic, V.; Fernandez, J.-J.<br>
# Robust Membrane Detection Based on Tensor Voting for Electron Tomography<br>
# J. Struct. Biol. 2014, 186 (1), 49–61. https://doi.org/10.1016/j.jsb.2014.02.015**

# %%
generate_tensor_voting_gui()
# Out:
# ...
# Button(description='Run TV Pipeline', style=ButtonStyle())
# Button(description='Set optmized default', style=ButtonStyle())

# %% [markdown]
# # 2) Load Segmented MRC and Convert to Point Cloud

# %%
gui = JupyterFramework()
gui.gui_elements_loading()

# %% [markdown]
# # 3) Visualize & Edit Segmentation 3D

# %%
gui.boot_gui()
# Out:
# ...
# <script>
#             $3Dmolpromise.then(function() { //wrap in promise for non-interactive functionality
#                 	viewer_1698839297948533.removeAllModels();
# 	viewer_1698839297948533.removeAllShapes();
# ...
